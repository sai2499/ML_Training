# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
import mglearn
import matplotlib.pyplot as plt
X_varied, y_varied = make_blobs(n_samples = 200, cluster_std= [1.0,2.5,0.5], random_state=170)
y_pred = KMeans(n_clusters=3, random_state=0).fit_predict(X_varied)
mglearn.discrete_scatter(X_varied[:,0], X_varied[:,1],y_pred)
plt.legend(["Cluster0","cluster1","Cluster2"], loc='best')
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
# Out:
# Text(0, 0.5, 'Feature 1')

# %%
'''
1. The lower left dense region is expected to be the first cluster.
2. The upper right dense region is expected to be the second cluster, and the less dense region in the center is the third.
3. Instead, both cluster 0 and cluster 1 have some points that are far away from all the other points in these clusters that 
reach towards center
'''

# %%
import numpy as np
X, y= make_blobs(n_samples = 600, random_state=170)
rng= np.random.RandomState(74)
transformation = rng.normal(size=(2,2))
X = np.dot(X, transformation)
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
y_pred=kmeans.predict(X)
mglearn.discrete_scatter(X[:,0],X[:,1],kmeans.labels_, markers='o')
mglearn.discrete_scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1],[0,1,2],markers='^', markeredgewidth=2)

# %%
'''
1. kmeans assumes that all the directions are equally important for each cluster.
2. The plot above shows a 2d dataset where there are three clearly seperated parts in the data.
3. These groups are stretched towards teh diagonal. As kmeans only considers the distance to the nearest cluster center, it cant
handle this kind of data.
'''

# %%
from sklearn.datasets import make_moons
X, y= make_moons(n_samples = 200,noise=0.05,random_state=0)
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
y_pred=kmeans.predict(X)
plt.scatter(X[:,0],X[:,1],c=y_pred, cmap=mglearn.cm2,s=60, edgecolor='k')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1],[0,1,2],markers='^',
                        c=[mglearn.cm2(0), mglearn.cm2(1)], s=100, linewidth=2,edgecolor='k')
plt.xlabel("Feature 0")
plt.ylabel("Feature 1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f1031e2a0b51> in <module>
#       5 y_pred=kmeans.predict(X)
#       6 plt.scatter(X[:,0],X[:,1],c=y_pred, cmap=mglearn.cm2,s=60, edgecolor='k')
# ----> 7 plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1],[0,1,2],markers='^',
#       8                         c=[mglearn.cm2(0), mglearn.cm2(1)], s=100, linewidth=2,edgecolor='k')
#       9 plt.xlabel("Feature 0")
#
# TypeError: scatter() got multiple values for argument 's'

# %%
'''
k-means also performs poorly if the clusters have more comples shapes, like the two moons data.
'''
